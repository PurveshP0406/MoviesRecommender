# %% [markdown]
# # Item based collaborative filtering python

# %%
#importing neccesary packages
import pandas as pd 
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Step 1 - Data Preparation

# %%
#Reading movielens data from 
#https://grouplens.org/datasets/movielens/
my_df = pd.read_csv('/Users/vishalsolanki/Desktop/movieRecommender/ml-100k/u.data', sep='\t', names=['user_id','item_id','rating','timestamp'])

# %%
#Checking Data
my_df.head()
# Out:
#    user_id  item_id  rating  timestamp
# 0      196      242       3  881250949
# 1      186      302       3  891717742
# 2       22      377       1  878887116
# 3      244       51       2  880606923
# 4      166      346       1  886397596

# %%
#Importing movie title and joining with main data
movie_titles = pd.read_csv('/Users/vishalsolanki/Desktop/movieRecommender/Movie_Titles.csv',encoding= 'unicode_escape')
my_df = pd.merge(my_df, movie_titles, on='item_id')
my_df.head()
# Out:
#    user_id  item_id  rating  timestamp         title
# 0      196      242       3  881250949  Kolya (1996)
# 1       63      242       3  875747190  Kolya (1996)
# 2      226      242       5  883888671  Kolya (1996)
# 3      154      242       3  879138235  Kolya (1996)
# 4      306      242       5  876503793  Kolya (1996)

# %% [markdown]
# # user_id - the ID of the user who rated the movie.
# # item_id - the ID of the movie.
# # rating - The rating the user gave the movie, between 1 and 5.
# # timestamp - The time the movie was rated.
# # title - The title of the movie.

# %% [markdown]
# # Step 2 - Data exploration

# %%
#Statitical features of the movie
my_df.describe()
# Out:
#             user_id        item_id         rating     timestamp
# count  100000.00000  100000.000000  100000.000000  1.000000e+05
# mean      462.48475     425.530130       3.529860  8.835289e+08
# std       266.61442     330.798356       1.125674  5.343856e+06
# min         1.00000       1.000000       1.000000  8.747247e+08
# 25%       254.00000     175.000000       3.000000  8.794487e+08
# 50%       447.00000     322.000000       4.000000  8.828269e+08
# 75%       682.00000     631.000000       4.000000  8.882600e+08
# max       943.00000    1682.000000       5.000000  8.932866e+08

# %%
#creating mean ratings data
ratings = pd.DataFrame(my_df.groupby('title')['rating'].mean())
my_df['title'].head()
# Out:
# 0    Kolya (1996)
# 1    Kolya (1996)
# 2    Kolya (1996)
# 3    Kolya (1996)
# 4    Kolya (1996)
# Name: title, dtype: object

# %%
import pickle
pickle.dump(my_df,open('names.pkl','wb'))

# %% [markdown]
# # Creating User - Item interaction matrix

# %%
ratings.columns
# Out:
# Index(['rating', 'number_of_ratings'], dtype='object')

# %%
#creating number of ratings data
ratings['number_of_ratings'] = my_df.groupby('title')['rating'].count()
ratings.head()
# Out:
#                              rating  number_of_ratings
# title
# 'Til There Was You (1997)  2.333333                  9
# 1-900 (1994)               2.600000                  5
# 101 Dalmatians (1996)      2.908257                109
# 12 Angry Men (1957)        4.344000                125
# 187 (1997)                 3.024390                 41

# %%
ratings.to_dict()
# Out:
# {'rating': {"'Til There Was You (1997)": 2.3333333333333335,
#   '1-900 (1994)': 2.6,
#   '101 Dalmatians (1996)': 2.908256880733945,
#   '12 Angry Men (1957)': 4.344,
#   '187 (1997)': 3.024390243902439,
#   '2 Days in the Valley (1996)': 3.225806451612903,
#   '20,000 Leagues Under the Sea (1954)': 3.5,
#   '2001: A Space Odyssey (1968)': 3.969111969111969,
#   '3 Ninjas: High Noon At Mega Mountain (1998)': 1.0,
#   '39 Steps, The (1935)': 4.0508474576271185,
#   '8 1/2 (1963)': 3.8157894736842106,
#   '8 Heads in a Duffel Bag (1997)': 3.25,
#   '8 Seconds (1994)': 3.75,
#   '? k\x94ldum klaka (Cold Fever) (1994)': 3.0,
#   'A Chef in Love (1996)': 4.125,
#   'Above the Rim (1994)': 3.0,
#   'Absolute Power (1997)': 3.37007874015748,
#   'Abyss, The (1989)': 3.589403973509934,
#   'Ace Ventura: Pet Detective (1994)': 3.0485436893203883,
#   'Ace Ventura: When Nature Calls (1995)': 2.675675675675676,
#   'Across the Sea of Time (1995)': 2.75,
# ...

# %%
ratings['index'].head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'index'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-49-e8af3dd544e3> in <module>
# ...

# %%
#Plotting the jointplot
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.jointplot(x='rating', y='number_of_ratings', data=ratings)

# %%
#creating the user-item interaction matrix
movie_matrix_UII = my_df.pivot_table(index='user_id', columns='title', values='rating')
movie_matrix_UII.head()
# Out:
# title    'Til There Was You (1997)  1-900 (1994)  101 Dalmatians (1996)  \
# user_id
# 1                              NaN           NaN                    2.0
# 2                              NaN           NaN                    NaN
# 3                              NaN           NaN                    NaN
# 4                              NaN           NaN                    NaN
# 5                              NaN           NaN                    2.0
#
# title    12 Angry Men (1957)  187 (1997)  2 Days in the Valley (1996)  \
# user_id
# 1                        5.0         NaN                          NaN
# 2                        NaN         NaN                          NaN
# 3                        NaN         2.0                          NaN
# 4                        NaN         NaN                          NaN
# 5                        NaN         NaN                          NaN
#
# title    20,000 Leagues Under the Sea (1954)  2001: A Space Odyssey (1968)  \
# user_id
# ...

# %%
movie_matrix_UII[columns='title'].head()
# Out:
#   File "<ipython-input-45-2c0507c33bd3>", line 1
#     movie_matrix_UII[columns='title'].head()
#                             ^
# SyntaxError: invalid syntax

# %%
#Most rated movies
ratings.sort_values('number_of_ratings', ascending=False).head(10)
Movie_Titles.csv
# Out:
#                                  rating  number_of_ratings
# title
# Star Wars (1977)               4.358491                583
# Contact (1997)                 3.803536                509
# Fargo (1996)                   4.155512                508
# Return of the Jedi (1983)      4.007890                507
# Liar Liar (1997)               3.156701                485
# English Patient, The (1996)    3.656965                481
# Scream (1996)                  3.441423                478
# Toy Story (1995)               3.878319                452
# Air Force One (1997)           3.631090                431
# Independence Day (ID4) (1996)  3.438228                429

# %%
ratings['title'].head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'title'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-58019b0d77ec> in <module>
# ...

# %%
import pickle
pickle.dump(movie_matrix_UII,open('user_ratings.pkl','wb'))

# %%
pickle.dump(movie_matrix_UII.to_dict(),open('matrix_dict.pkl','wb'))

# %%
ratings.to_dict()
# Out:
# {'rating': {"'Til There Was You (1997)": 2.3333333333333335,
#   '1-900 (1994)': 2.6,
#   '101 Dalmatians (1996)': 2.908256880733945,
#   '12 Angry Men (1957)': 4.344,
#   '187 (1997)': 3.024390243902439,
#   '2 Days in the Valley (1996)': 3.225806451612903,
#   '20,000 Leagues Under the Sea (1954)': 3.5,
#   '2001: A Space Odyssey (1968)': 3.969111969111969,
#   '3 Ninjas: High Noon At Mega Mountain (1998)': 1.0,
#   '39 Steps, The (1935)': 4.0508474576271185,
#   '8 1/2 (1963)': 3.8157894736842106,
#   '8 Heads in a Duffel Bag (1997)': 3.25,
#   '8 Seconds (1994)': 3.75,
#   '? k\x94ldum klaka (Cold Fever) (1994)': 3.0,
#   'A Chef in Love (1996)': 4.125,
#   'Above the Rim (1994)': 3.0,
#   'Absolute Power (1997)': 3.37007874015748,
#   'Abyss, The (1989)': 3.589403973509934,
#   'Ace Ventura: Pet Detective (1994)': 3.0485436893203883,
#   'Ace Ventura: When Nature Calls (1995)': 2.675675675675676,
#   'Across the Sea of Time (1995)': 2.75,
# ...

# %% [markdown]
# # Making recommendation - Example movie- FARGO

# %%
#Fetching ratings for Fargo
Fargo_user_rating = movie_matrix_UII['Fargo (1996)']

# %%
#Finding the correlation with different movies
similar_to_fargo=movie_matrix_UII.corrwith(Fargo_user_rating)

# %%
#Observing the result
similar_to_fargo.head()
# Out:
# title
# 'Til There Was You (1997)    0.100000
# 1-900 (1994)                 0.866025
# 101 Dalmatians (1996)       -0.245368
# 12 Angry Men (1957)          0.098676
# 187 (1997)                   0.142509
# dtype: float64

# %% [markdown]
# # creating a threshold for minimum number of ratings

# %% [markdown]
# # Next - User based recommendation - On Demand

# %%
#creating dataframe to bring in #of ratings
corr_fargo = pd.DataFrame(similar_to_fargo, columns=['Correlation'])
corr_fargo.dropna(inplace=True)
corr_fargo.head()
# Out:
#                            Correlation
# title
# 'Til There Was You (1997)     0.100000
# 1-900 (1994)                  0.866025
# 101 Dalmatians (1996)        -0.245368
# 12 Angry Men (1957)           0.098676
# 187 (1997)                    0.142509

# %%
corr_fargo[corr_fargo['number_of_ratings'] > 30].sort_values(by='Correlation', ascending=False).head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-58902391b33f> in <module>
# ----> 1 corr_fargo[corr_fargo['number_of_ratings'] > 30].sort_values(by='Correlation', ascending=False).head(10)
#
# NameError: name 'corr_fargo' is not defined

# %%
#Bringining in ratings
corr_fargo = corr_fargo.join(ratings['number_of_ratings'])

corr_fargo.head()
# Out:
#                            Correlation  number_of_ratings
# title
# 'Til There Was You (1997)     0.100000                  9
# 1-900 (1994)                  0.866025                  5
# 101 Dalmatians (1996)        -0.245368                109
# 12 Angry Men (1957)           0.098676                125
# 187 (1997)                    0.142509                 41
